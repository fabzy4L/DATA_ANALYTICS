# %% [markdown]
# # QPCR CT VALUE DATA TRANSFORMATION

# %%
import pandas as pd
from scipy import stats
import matplotlib.pyplot as plt
import statsmodels.api as sm
from sklearn.preprocessing import MinMaxScaler
import numpy as np
from sklearn.linear_model import LinearRegression

# %%
df = pd.read_csv('https://raw.githubusercontent.com/fabzy4L/DATA_ANALYTICS/main/GENE_EXPRESSION%20NICOTINE_R/qPCRCTValues.csv')

# %%
print(df)
# Out:
#      PLATE WELL Target Name SAMPLE      GENEID            CT
# 0        1   A1       INSRR   100%      INSRR1       29.5760
# 1        1   A2       INSRR    10%    INSRR0.1       32.3810
# 2        1   A3       INSRR     1%   INSRR0.01       36.3370
# 3        1   A4       INSRR  0.10%  INSRR0.001  Undetermined
# 4        1   A5       INSRR     C1     INSRRC1       30.1750
# ..     ...  ...         ...    ...         ...           ...
# 303      7  E10        FGF1     V5      FGF1V5       22.2950
# 304      7  E11        FGF1     V7      FGF1V7       22.9350
# 305      7  E12        FGF1     V8      FGF1V8       23.0470
# 306      7   F5        FGF1    V10     FGF1V10       23.2250
# 307      7   F6        FGF1    V12     FGF1V12       23.5620
#
# [308 rows x 6 columns]

# %%
df.columns.tolist()
# Out:
# ['PLATE', 'WELL', 'Target Name', 'SAMPLE', 'GENEID', 'CT']

# %%
name_values = df['Target Name'].unique()
name_values
# Out:
# array(['INSRR', 'GAPDH', 'IGF2', 'CCL2', 'BCAS1', 'MOBP', 'PAIPB',
#        'SLC27A6', 'MBP', 'COL1A1', 'CDH19', 'ERNM', 'OPALIN', 'FGF1'],
#       dtype=object)

# %%
rdf = df[['SAMPLE','Target Name','CT']]
rdf
# Out:
#     SAMPLE Target Name            CT
# 0     100%       INSRR       29.5760
# 1      10%       INSRR       32.3810
# 2       1%       INSRR       36.3370
# 3    0.10%       INSRR  Undetermined
# 4       C1       INSRR       30.1750
# ..     ...         ...           ...
# 303     V5        FGF1       22.2950
# 304     V7        FGF1       22.9350
# 305     V8        FGF1       23.0470
# 306    V10        FGF1       23.2250
# 307    V12        FGF1       23.5620
#
# [308 rows x 3 columns]

# %%
GAPDH = df[(df['Target Name'] == 'GAPDH') ]
GAPDH = GAPDH[['Target Name', 'SAMPLE', 'CT']]
GAPDH_LM = GAPDH.iloc[:4,:]
GAPDH_VDS = GAPDH.iloc[4:,:]
GAPDH_VDS = GAPDH_VDS['CT'].to_numpy()
GAPDH_VDS = GAPDH_VDS.tolist()
GAPDH_LM
# Out:
#    Target Name SAMPLE       CT
# 22       GAPDH   100%  14.9710
# 23       GAPDH    10%  17.7530
# 24       GAPDH     1%  21.1390
# 25       GAPDH  0.10%  24.7670

# %%
GAPDH_VDS
# Out:
# ['14.6760',
#  '14.8820',
#  '15.2700',
#  '16.2830',
#  '17.6380',
#  '15.2660',
#  '15.6480',
#  '15.7670',
#  '15.6550',
#  '15.8530',
#  '15.4300',
#  '15.7410',
#  '15.4910',
#  '14.5080',
#  '15.2610',
#  '15.5710',
#  '16.3410',
#  '16.2380']

# %%
##CALIBRATORS
y = (1,0.1,0.01,0.001)
ylog = np.log10(y)
ylog = ylog.tolist()
df_ycal = pd.DataFrame(ylog)
df_ycal
# Out:
#      0
# 0  0.0
# 1 -1.0
# 2 -2.0
# 3 -3.0

# %%
rdf_samples = rdf['SAMPLE']
#.unique()
rdf_samples = rdf_samples.unique()
rdf_samples = rdf_samples.tolist()
rdf_samples = pd.DataFrame(rdf_samples)
#rdf_cal = rdf_samples.iloc[:4,:]
rdf_samples = rdf_samples.iloc[4:,:]
rdf_samples
# Out:
#       0
# 4    C1
# 5    C2
# 6    C3
# 7    C5
# 8    C6
# 9    C7
# 10  C10
# 11  C11
# 12  C12
# 13   V1
# 14   V2
# 15   V3
# 16   V4
# 17   V5
# 18   V7
# 19   V8
# 20  V10
# 21  V12

# %%
df_xcal = GAPDH_LM['CT'].tolist()
df_xcal = pd.DataFrame(df_xcal)
df_xcal
# Out:
#          0
# 0  14.9710
# 1  17.7530
# 2  21.1390
# 3  24.7670

# %%
df_cal = pd.concat([df_xcal, df_ycal], axis=1, ignore_index=True)
df_cal
# Out:
#          0    1
# 0  14.9710  0.0
# 1  17.7530 -1.0
# 2  21.1390 -2.0
# 3  24.7670 -3.0

# %%
df_cal = df_cal.rename(columns={'NewName1': 'CT', 'NewName2': 'log(y)'})

df_cal.columns.tolist()
df_cal
# Out:
#         CT  log(y)
# 0  14.9710     0.0
# 1  17.7530    -1.0
# 2  21.1390    -2.0
# 3  24.7670    -3.0

# %%
# Extract the columns you want to plot
GAPDH_LMX = df_cal[['CT']].to_numpy()
GAPDH_LMY = df_cal[['log(y)']].to_numpy()

#X_train, X_test, y_train, y_test = train_test_split(GAPDH_LMX, GAPDH_LMY, test_size=0.2, random_state=42)

# Create a linear regression model
model = LinearRegression()

# Train the model on the training data
model.fit(GAPDH_LMX, GAPDH_LMY)

# Evaluate the model on the testing data
r_squared = model.score(GAPDH_LMX, GAPDH_LMY)
print(f"R-squared: {r_squared}")
# Out:
# R-squared: 0.9965582945298149

# %%
plt.scatter(GAPDH_LMX.tolist(), GAPDH_LMY.tolist())  # Scatter plot

# Add labels and a title
plt.xlabel('Ct')
plt.ylabel('log(%)')
plt.title('Scatter Plot of GAPDH log(%) vs. GAPDH Ct')

# Show the plot
plt.show()

# %%
# Create a LinearRegression model
model = LinearRegression()

# Fit the model to the data
model.fit(GAPDH_LMX, GAPDH_LMY)

# Get the coefficients and intercept
coefficients = model.coef_
intercept = model.intercept_

# Make predictions
predictions = model.predict(GAPDH_LMX)

# Calculate R-squared
r_squared = model.score(GAPDH_LMX, GAPDH_LMY)

# Calculate Slope
slope = model.coef_[0]

print("R-squared:", r_squared)
print(f"Slope: {slope}")
print("Intercept:", intercept)
print("Coefficients:", coefficients)
# Out:
# R-squared: 0.9965582945298149
# Slope: [-0.30406978]
# Intercept: [4.47725169]
# Coefficients: [[-0.30406978]]

# %%
#y = mx + b

def yfxn(x):
    """THIS FUNCTION CALCULATES SLOPE"""
    y = 10 ** ((-0.30406978 * x ) + 4.47725169)
    return y

# %%
GAPDH
# Out:
#    Target Name SAMPLE      CT
# 22       GAPDH   100%  14.971
# 23       GAPDH    10%  17.753
# 24       GAPDH     1%  21.139
# 25       GAPDH  0.10%  24.767
# 26       GAPDH     C1  14.676
# 27       GAPDH     C2  14.882
# 28       GAPDH     C3  15.270
# 29       GAPDH     C5  16.283
# 30       GAPDH     C6  17.638
# 31       GAPDH     C7  15.266
# 32       GAPDH    C10  15.648
# 33       GAPDH    C11  15.767
# 34       GAPDH    C12  15.655
# 35       GAPDH     V1  15.853
# 36       GAPDH     V2  15.430
# 37       GAPDH     V3  15.741
# 38       GAPDH     V4  15.491
# 39       GAPDH     V5  14.508
# 40       GAPDH     V7  15.261
# 41       GAPDH     V8  15.571
# 42       GAPDH    V10  16.341
# 43       GAPDH    V12  16.238

# %%
# Assuming ct_data is a NumPy array
GAPDH_VDS = GAPDH_VDS['CT'].to_numpy(dtype=float)  # Convert to float NumPy array

# Calculate the slope using the yfxn function
GAPDH_slopes = yfxn(GAPDH_VDS)
slopes.tolist()
# Out:
# [1.034483573019855,
#  0.8955404852358891,
#  0.6825054904015793,
#  0.33580214214730425,
#  0.13003758948664804,
#  0.6844195848815772,
#  0.5238027480573165,
#  0.48192945280830696,
#  0.5212418578961392,
#  0.4537675838894248,
#  0.6101758075527252,
#  0.49078274237296954,
#  0.5846645042107014,
#  1.1636096700862362,
#  0.6868197536354287,
#  0.5528166891610234,
#  0.3224388882188334,
#  0.3465505579162425]

# %%
# Filtering rows where Age is greater than 25 and Salary is less than 60000
INSRR = df[(df['Target Name'] == 'INSRR') ]

INSRR_CAL = INSRR.iloc[:4,:]
INSRR_VDS = INSRR.iloc[4:,:]
INSRR_VDS = INSRR_VDS[['CT']].to_numpy(dtype=float)
INSRR_VDS
# Out:
# array([[30.175],
#        [29.72 ],
#        [31.24 ],
#        [31.824],
#        [34.312],
#        [30.291],
#        [30.339],
#        [30.272],
#        [30.921],
#        [29.927],
#        [29.595],
#        [30.198],
#        [30.583],
#        [29.432],
#        [29.405],
#        [30.904],
#        [31.562],
#        [31.641]])

# %%
PAIPB = df[(df['Target Name'] == 'PAIPB') ]
PAIPB = PAIPB[['Target Name', 'SAMPLE', 'GENEID', 'CT']]
PAIPB

# %% [markdown]
# # QPCR CT VALUE DATA TRANSFORMATION

# %%
import pandas as pd
from scipy import stats
import matplotlib.pyplot as plt
import statsmodels.api as sm
from sklearn.preprocessing import MinMaxScaler
import numpy as np
from sklearn.linear_model import LinearRegression
from sklearn.impute import SimpleImputer  # Import SimpleImputer

# %%
df = pd.read_csv('https://raw.githubusercontent.com/fabzy4L/DATA_ANALYTICS/main/GENE_EXPRESSION%20NICOTINE_R/qPCRCTValues.csv')

# %%
print(df)
# Out:
#      PLATE WELL Target Name SAMPLE      GENEID            CT
# 0        1   A1       INSRR   100%      INSRR1       29.5760
# 1        1   A2       INSRR    10%    INSRR0.1       32.3810
# 2        1   A3       INSRR     1%   INSRR0.01       36.3370
# 3        1   A4       INSRR  0.10%  INSRR0.001  Undetermined
# 4        1   A5       INSRR     C1     INSRRC1       30.1750
# ..     ...  ...         ...    ...         ...           ...
# 303      7  E10        FGF1     V5      FGF1V5       22.2950
# 304      7  E11        FGF1     V7      FGF1V7       22.9350
# 305      7  E12        FGF1     V8      FGF1V8       23.0470
# 306      7   F5        FGF1    V10     FGF1V10       23.2250
# 307      7   F6        FGF1    V12     FGF1V12       23.5620
#
# [308 rows x 6 columns]

# %%
df.columns.tolist()
# Out:
# ['PLATE', 'WELL', 'Target Name', 'SAMPLE', 'GENEID', 'CT']

# %%
name_values = df['Target Name'].unique()
name_values = name_values.tolist()
name_values
# Out:
# ['INSRR',
#  'GAPDH',
#  'IGF2',
#  'CCL2',
#  'BCAS1',
#  'MOBP',
#  'PAIPB',
#  'SLC27A6',
#  'MBP',
#  'COL1A1',
#  'CDH19',
#  'ERNM',
#  'OPALIN',
#  'FGF1']

# %%
txt = input()
txt = txt.upper()
txt

# %%
rdf = df[['SAMPLE','Target Name','CT']]
rdf = rdf.rename(columns={'SAMPLE': 'SAMPLE', 'Target Name':'GENE', 'CT':'CT'})
rdf
# Out:
#     SAMPLE   GENE            CT
# 0     100%  INSRR       29.5760
# 1      10%  INSRR       32.3810
# 2       1%  INSRR       36.3370
# 3    0.10%  INSRR  Undetermined
# 4       C1  INSRR       30.1750
# ..     ...    ...           ...
# 303     V5   FGF1       22.2950
# 304     V7   FGF1       22.9350
# 305     V8   FGF1       23.0470
# 306    V10   FGF1       23.2250
# 307    V12   FGF1       23.5620
#
# [308 rows x 3 columns]

# %%
# Create an empty dictionary to store the smaller DataFrames
dfs_by_gene = {}

# Loop through unique values in the 'Category' column
for gene in rdf['GENE'].unique():
    # Filter the DataFrame based on the 'Category' column
    filtered_df = rdf[rdf['GENE'] == gene]
    
    # Store the filtered DataFrame in the dictionary
    dfs_by_gene[gene] = filtered_df

# %%
# Now, dfs_by_category contains smaller DataFrames for each unique category
# You can access them like this:
dfs_by_gene['INSRR'] = dfs_by_gene['INSRR'].reset_index(drop=True)
dfs_by_gene['GAPDH'] = dfs_by_gene['GAPDH'].reset_index(drop=True)
dfs_by_gene['IGF2'] = dfs_by_gene['IGF2'].reset_index(drop=True)
dfs_by_gene['CCL2'] = dfs_by_gene['CCL2'].reset_index(drop=True)
dfs_by_gene['BCAS1'] = dfs_by_gene['BCAS1'].reset_index(drop=True)
dfs_by_gene['MOBP'] = dfs_by_gene['MOBP'].reset_index(drop=True)
dfs_by_gene['PAIPB'] = dfs_by_gene['PAIPB'].reset_index(drop=True)
dfs_by_gene['SLC27A6'] = dfs_by_gene['SLC27A6'].reset_index(drop=True)
dfs_by_gene['MBP'] = dfs_by_gene['MBP'].reset_index(drop=True)
dfs_by_gene['COL1A1'] = dfs_by_gene['COL1A1'].reset_index(drop=True)
dfs_by_gene['CDH19'] = dfs_by_gene['CDH19'].reset_index(drop=True)
dfs_by_gene['ERNM'] = dfs_by_gene['ERNM'].reset_index(drop=True)
dfs_by_gene['OPALIN'] = dfs_by_gene['OPALIN'].reset_index(drop=True)
dfs_by_gene['FGF1'] = dfs_by_gene['FGF1'].reset_index(drop=True)

GAPDH	 = 	dfs_by_gene['GAPDH']
INSRR	 = 	dfs_by_gene['INSRR']
IGF2	 = 	dfs_by_gene['IGF2']
CCL2	 = 	dfs_by_gene['CCL2']
BCAS1	 = 	dfs_by_gene['BCAS1']
MOBP	 = 	dfs_by_gene['MOBP']
PAIPB	 = 	dfs_by_gene['PAIPB']
SLC27A6	 = 	dfs_by_gene['SLC27A6']
MBP	 = 	dfs_by_gene['MBP']
COL1A1	 = 	dfs_by_gene['COL1A1']
CDH19	 = 	dfs_by_gene['COL1A1']
ERNM	 = 	dfs_by_gene['ERNM']
OPALIN	 = 	dfs_by_gene['OPALIN']
FGF1	 = 	dfs_by_gene['FGF1']

GAPDH	 = 	GAPDH.rename(columns={'CT':'GAPDH'})
INSRR	 = 	INSRR.rename(columns={'CT':'INSRR'})
IGF2	 = 	IGF2.rename(columns={'CT':'IGF2'})
CCL2	 = 	CCL2.rename(columns={'CT':'CCL2'})
BCAS1	 = 	BCAS1.rename(columns={'CT':'BCAS1'})
MOBP	 = 	MOBP.rename(columns={'CT':'MOBP'})
PAIPB	 = 	PAIPB.rename(columns={'CT':'PAIPB'})
SLC27A6	 = 	SLC27A6.rename(columns={'CT':'SLC27A6'})
MBP	 = 	MBP.rename(columns={'CT':'MBP'})
COL1A1	 = 	COL1A1.rename(columns={'CT':'COL1A1'})
CDH19	 = 	CDH19.rename(columns={'CT':'CDH19'})
ERNM	 = 	ERNM.rename(columns={'CT':'ERNM'})
OPALIN	 = 	OPALIN.rename(columns={'CT':'OPALIN'})
FGF1	 = 	FGF1.rename(columns={'CT':'FGF1'})

GAPDH_CT = GAPDH[['GAPDH']]
INSRR_CT = INSRR[['INSRR']]
IGF2_CT = IGF2[['IGF2']]
CCL2_CT = CCL2[['CCL2']]
BCAS1_CT = BCAS1[['BCAS1']]
MOBP_CT = MOBP[['MOBP']]
PAIPB_CT = PAIPB[['PAIPB']]
SLC27A6_CT = SLC27A6[['SLC27A6']]
MBP_CT = MBP[['MBP']]
COL1A1_CT = COL1A1[['COL1A1']]
CDH19_CT = CDH19[['CDH19']]
ERNM_CT = ERNM[['ERNM']]
OPALIN_CT = OPALIN[['OPALIN']]
FGF1_CT = FGF1[['FGF1']]

# %%
rdf_samples = rdf['SAMPLE']
rdf_samples = rdf_samples.unique()
rdf_samples = rdf_samples.tolist()
rdf_samples = pd.DataFrame(rdf_samples)
# 10  23.168        31.187  19.6890  26.2400  26.2400  23.9350  26.9260  23.3730
# 11  23.205        31.809  20.0810  26.4420  26.4420  24.7210  27.5190  23.6040
# 12  23.213        31.469  19.7580  25.8260  25.8260  24.0830  27.6560  23.2820
# 13   23.01        31.498  20.1310  25.9890  25.9890  24.5830  27.6580  23.3770
# 14  22.655        31.662  20.6950  26.1960  26.1960  24.8540  27.5370  23.0410
# 15   22.47        31.102  20.7850  26.1210  26.1210  24.7840  27.9410  23.0340
# 16  23.017        31.785  20.0160  26.5150  26.5150  24.2090  27.0370  23.3130
# 17  21.754        30.372  19.2220  25.8530  25.8530  23.5340  26.3750  22.2950
# 18  22.535        31.289  20.3850  25.5170  25.5170  24.9730  27.6050  22.9350
# 19  22.621        33.594  19.5380  26.8940  26.8940  24.2530  26.6340  23.0470
# 20  23.228         31.86  19.9110  27.0240  27.0240  24.3900  27.4190  23.2250
# 21  23.271        32.264  20.9310  27.5560  27.5560  24.7730  27.9600  23.5620

# %%
samples_df = matrix_df.iloc[4:,:]
samples_df = samples_df.reset_index(drop=True)
rdf_test = samples_df.iloc[:,:1]

# %%
calibrator_df = matrix_df.iloc[:4,:]
calibrator_df
# Out:
#   SAMPLE    GAPDH         INSRR     IGF2          CCL2    BCAS1     MOBP  \
# 0   100%  14.9710       29.5760  22.0550       30.8810  28.9980  30.1330
# 1    10%  17.7530       32.3810  25.1170       33.7820  27.7220  25.8320
# 2     1%  21.1390       36.3370  28.6210       37.1570  31.8770  29.3060
# 3  0.10%  24.7670  Undetermined  32.0790  Undetermined  34.1450  32.2680
#
#     PAIPB       SLC27A6      MBP   COL1A1    CDH19     ERNM   OPALIN     FGF1
# 0  21.808         30.65  18.9820  26.2430  26.2430  24.7830  26.4750  22.3600
# 1  25.059        33.799  22.2360  28.1800  28.1800  26.4020  29.7130  25.6620
# 2   28.38        36.702  25.6740  31.6880  31.6880  30.0760  32.7760  28.7530
# 3  31.864  Undetermined  28.8410  35.5820  35.5820  32.4040  35.9700  32.2230

# %%
calibrator_df.columns
# Out:
# Index(['SAMPLE', 'GAPDH', 'INSRR', 'IGF2', 'CCL2', 'BCAS1', 'MOBP', 'PAIPB',
#        'SLC27A6', 'MBP', 'COL1A1', 'CDH19', 'ERNM', 'OPALIN', 'FGF1'],
#       dtype='object')

# %%
# Function to safely convert a value to numeric
def safe_to_numeric(value):
    try:
        return pd.to_numeric(value)
    except ValueError:
        return value  # Return the original value if conversion fails


# Apply the safe_to_numeric function to all elements in the DataFrame
calibrator_df = calibrator_df.applymap(safe_to_numeric)
samples_df = samples_df.applymap(safe_to_numeric)
samples_df
# Out:
#    SAMPLE   GAPDH   INSRR    IGF2    CCL2   BCAS1    MOBP   PAIPB  SLC27A6  \
# 0      C1  14.676  30.175  22.983  30.827  25.634  23.562  22.893   30.779
# 1      C2  14.882  29.720  22.133  31.850  25.872  24.223  22.436   30.746
# 2      C3  15.270  31.240  22.973  31.947  25.635  23.437  22.742   31.359
# 3      C5  16.283  31.824  24.187  33.406  26.234  24.343  23.482   32.103
column_dtype = samples_df['GAPDH'].dtype
column_dtype
# Out:
# dtype('float64')

# %%
# Select Column A as Y
Y = (0,-1,-2,-3)
# Create a DataFrame to store the results

#results = pd.DataFrame(columns=['Column', 'R-squared', 'Intercept', 'Slope'])
results_list = []

# Loop through the other columns (B, C, D, E)
for column_name in ['GAPDH', 'INSRR', 'IGF2', 'CCL2', 'BCAS1', 'MOBP', 'PAIPB',
       'SLC27A6', 'MBP', 'COL1A1', 'CDH19', 'ERNM', 'OPALIN', 'FGF1']:
    X = calibrator_df[column_name].values.reshape(-1, 1)  # Reshape to a 2D array
    
    imputer = SimpleImputer(strategy='mean')  # You can choose a different strategy if needed
    X = imputer.fit_transform(X)
    
    model = LinearRegression().fit(X, Y)
    
    # Calculate R-squared
    r_squared = model.score(X, Y)
    
    # Get intercept and slope
    intercept = model.intercept_
    slope = model.coef_[0]
    
      # Create a DataFrame for the current column's results
    column_results = pd.DataFrame({
        'Gene': [column_name],
        'R-squared': [r_squared],
        'Intercept': [intercept],
        'Slope': [slope]
    })
    
     # Append the current column's results to the list
    results_list.append(column_results)
    
    
 # Append results to the DataFrame
    #results = results.append({'Column': column_name, 'R-squared': r_squared, 'Intercept': intercept, 'Slope': slope}, ignore_index=True)

# Concatenate the list of DataFrames into one DataFrame
results = pd.concat(results_list, ignore_index=True)

results
# Out:
#        Gene  R-squared  Intercept     Slope
# 0     GAPDH   0.996558   4.477252 -0.304070
# 1     INSRR   0.396173   8.099517 -0.292984
# 2      IGF2   0.999094   6.524651 -0.297562
# 3      CCL2   0.399241   9.295280 -0.318070
# 4     BCAS1   0.767460  10.517704 -0.391641
# 5      MOBP   0.226951   5.250585 -0.229731
# 6     PAIPB   0.999750   6.493987 -0.298531
# 7   SLC27A6   0.399780   9.636299 -0.330287
# 8       MBP   0.999775   5.747577 -0.302825
# 9    COL1A1   0.979738   7.954976 -0.310781
# 10    CDH19   0.979738   7.954976 -0.310781
# 11     ERNM   0.980398   8.998257 -0.369446
# 12   OPALIN   0.999896   8.399283 -0.316944
# 13     FGF1   0.999542   6.834462 -0.305857

# %%
# Filter the results by R^2:
results_filtered = results[results['R-squared'] >= 0.9]
results_filtered
# Out:
#       Gene  R-squared  Intercept     Slope
# 0    GAPDH   0.996558   4.477252 -0.304070
# 2     IGF2   0.999094   6.524651 -0.297562
# 6    PAIPB   0.999750   6.493987 -0.298531
# 8      MBP   0.999775   5.747577 -0.302825
# 9   COL1A1   0.979738   7.954976 -0.310781
# 10   CDH19   0.979738   7.954976 -0.310781
# 11    ERNM   0.980398   8.998257 -0.369446
# 12  OPALIN   0.999896   8.399283 -0.316944
# 13    FGF1   0.999542   6.834462 -0.305857

# %%
column = results_filtered['Gene']
results_filtered_columns = column.tolist()
results_filtered_columns
# Out:
# ['GAPDH', 'IGF2', 'PAIPB', 'MBP', 'COL1A1', 'CDH19', 'ERNM', 'OPALIN', 'FGF1']

# %%
#y = mx + b

def yfxn(x, m, b):
    """THIS FUNCTION CALCULATES SLOPE"""
    y = 10 ** (m * x + b)
    return y

# %%
#LINEAR EQUATION GAPDH

#GAPDH_samples = yfxn(samples_df['GAPDH'],-0.304070,4.477252)
GAPDH_samples  =  yfxn(samples_df['GAPDH'] , -0.30407 , 4.477252 )
INSRR_samples  =  yfxn(samples_df['INSRR'] , -0.292984 , 8.099517 )
IGF2_samples  =  yfxn(samples_df['IGF2'] , -0.297562 , 6.524651 )
CCL2_samples  =  yfxn(samples_df['CCL2'] , -0.31807 , 9.29528 )
BCAS1_samples  =  yfxn(samples_df['BCAS1'] , -0.391641 , 10.517704 )
MOBP_samples  =  yfxn(samples_df['MOBP'] , -0.229731 , 5.250585 )
PAIPB_samples  =  yfxn(samples_df['PAIPB'] , -0.298531 , 6.493987 )
SLC27A6_samples  =  yfxn(samples_df['SLC27A6'] , -0.330287 , 9.636299 )
MBP_samples  =  yfxn(samples_df['MBP'] , -0.302825 , 5.747577 )
COL1A1_samples  =  yfxn(samples_df['COL1A1'] , -0.310781 , 7.954976 )
CDH19_samples  =  yfxn(samples_df['CDH19'] , -0.310781 , 7.954976 )
ERNM_samples  =  yfxn(samples_df['ERNM'] , -0.369446 , 8.998257 )
OPALIN_samples  =  yfxn(samples_df['OPALIN'] , -0.316944 , 8.399283 )
FGF1_samples  =  yfxn(samples_df['FGF1'] , -0.305857 , 6.834462 )

GAPDH_samples = pd.DataFrame(GAPDH_samples)
INSRR_samples = pd.DataFrame(INSRR_samples)
IGF2_samples = pd.DataFrame(IGF2_samples)
CCL2_samples = pd.DataFrame(CCL2_samples)
BCAS1_samples = pd.DataFrame(BCAS1_samples)
MOBP_samples = pd.DataFrame(MOBP_samples)
PAIPB_samples = pd.DataFrame(PAIPB_samples)
SLC27A6_samples = pd.DataFrame(SLC27A6_samples)
MBP_samples = pd.DataFrame(MBP_samples)
COL1A1_samples = pd.DataFrame(COL1A1_samples)
CDH19_samples = pd.DataFrame(CDH19_samples)
ERNM_samples = pd.DataFrame(ERNM_samples)
OPALIN_samples = pd.DataFrame(OPALIN_samples)
FGF1_samples = pd.DataFrame(FGF1_samples)

# %%
#rdf_test

# %%
data_frames_to_concat = [rdf_test, GAPDH_samples, INSRR_samples, IGF2_samples, CCL2_samples, BCAS1_samples, MOBP_samples, PAIPB_samples, SLC27A6_samples, MBP_samples, COL1A1_samples, CDH19_samples, ERNM_samples, OPALIN_samples, FGF1_samples]

samples_yfxn_df = pd.concat(data_frames_to_concat, axis=1)
# Assuming you have a DataFrame named samples_yfxn_df
# Reset the row index and create a new DataFrame with the corrected index
#samples_yfxn_df = samples_yfxn_df.reset_index(drop=True)

samples_yfxn_df
#GAPDH_samples
# Out:
#    SAMPLE     GAPDH     INSRR      IGF2      CCL2     BCAS1      MOBP  \
# 0      C1  1.034477  0.181437  0.485047  0.309126  3.008698  0.688118
# 1      C2  0.895534  0.246622  0.868383  0.146134  2.427549  0.485077
# 2      C3  0.682501  0.088450  0.488381  0.136112  3.005986  0.735156
# 3      C5  0.335800  0.059648  0.212578  0.046756  1.751435  0.455243
# 4      C6  0.130037  0.011134  0.050149  0.062395  1.254547  0.153270
# 5      C7  0.684415  0.167779  0.450142  0.162864  4.151399  0.582195
# 3   0.335800  0.059648  0.212578  0.046756  1.751435  0.455243  0.304707
# 4   0.130037  0.011134  0.050149  0.062395  1.254547  0.153270  0.111693
# 5   0.684415  0.167779  0.450142  0.162864  4.151399  0.582195  0.687611
# 6   0.523799  0.162433  0.473878  0.162031  2.642301  0.717863  0.378112
# 7   0.481926  0.169944  0.416891  0.083206  1.552080  0.361286  0.368617
# 8   0.521238  0.109688  0.399826  0.110633  2.431931  0.670512  0.366595
# 9   0.453764  0.214479  0.637982  0.135913  2.108978  0.475173  0.421491
# 10  0.610171  0.268322  0.617764  0.231811  1.275077  0.285057  0.537981
# 11  0.490779  0.178643  0.642368  0.145386  1.865559  0.404802  0.610936
# 12  0.584660  0.137780  0.393844  0.155976  2.407927  0.425664  0.419468
# 13  1.163602  0.299510  0.847226  0.278389  4.465986  0.498869  0.999410
# 14  0.686815  0.305016  0.858915  0.160967  1.927116  0.357106  0.584239
# 15  0.552813  0.110953  0.429650  0.100807  3.167394  0.564604  0.550703
# 16  0.322436  0.071180  0.335502  0.153821  2.599757  0.456932  0.362835
# 17  0.346548  0.067485  0.239330  0.105799  1.884156  0.255898  0.352267
#
#      SLC27A6       MBP    COL1A1     CDH19      ERNM    OPALIN      FGF1
# 0   0.295390  0.664049  0.506246  0.506246  1.434417  0.787032  0.558655
# 1   0.302897  0.429472  0.908385  0.908385  0.957610  0.657694  0.655039
# 2   0.190033  0.710517  0.583306  0.583306  2.099845  0.833132  0.495619
# 3   0.107918  0.381199  0.368447  0.368447  1.030293  0.432296  0.447506
# 4   0.044124  0.401945  0.129424  0.129424  0.811235  0.145300  0.351967
# 5   0.216920  0.796595  0.773294  0.773294  1.178510  0.799770  0.766432
# 6   0.216590  0.609896  0.631077  0.631077  1.430761  0.733245  0.484916
# 7   0.134958  0.464032  0.546141  0.546141  0.733132  0.475665  0.412110
# 8   0.174782  0.581247  0.848684  0.848684  1.261505  0.430407  0.517010
# 9   0.170970  0.448133  0.755246  0.755246  0.824453  0.429780  0.483552
# 10  0.150922  0.302422  0.651264  0.651264  0.654706  0.469457  0.612648
# 11  0.231054  0.284027  0.687172  0.687172  0.694876  0.349583  0.615675
# 12  0.137444  0.485548  0.518344  0.518344  1.133284  0.676189  0.505845
# 13  0.402552  0.844646  0.832444  0.832444  2.012402  1.096188  1.036049
# 14  0.200424  0.375396  1.058711  1.058711  0.591673  0.446729  0.660133
# 15  0.034725  0.677614  0.395214  0.395214  1.091649  0.907395  0.610064
# 16  0.129824  0.522430  0.360106  0.360106  0.971559  0.511676  0.538187
# 17  0.095481  0.256535  0.246090  0.246090  0.701409  0.344769  0.424482

# %%
# Specify the name of the specific column you want to divide by
housekeeping_gene = 'GAPDH'

# Divide all columns by the specific column
normalized_df = normalized_df.divide(normalized_df[housekeeping_gene], axis=0)

# %%
results_filtered_columns
# Out:
# ['GAPDH', 'IGF2', 'PAIPB', 'MBP', 'COL1A1', 'CDH19', 'ERNM', 'OPALIN', 'FGF1']

# %%
normalized_df = normalized_df[results_filtered_columns]
normalized_df = pd.concat([rdf_test, normalized_df], axis=1)
normalized_df
# Out:
#    SAMPLE  GAPDH      IGF2     PAIPB       MBP    COL1A1     CDH19      ERNM  \
# 0      C1    1.0  0.468881  0.441567  0.641918  0.489374  0.489374  1.386611
# 1      C2    1.0  0.969681  0.698334  0.479570  1.014350  1.014350  1.069316
# 2      C3    1.0  0.715577  0.742492  1.041049  0.854660  0.854660  3.076692
# 3      C5    1.0  0.633051  0.907406  1.135197  1.097223  1.097223  3.068179
# 4      C6    1.0  0.385650  0.858937  3.091013  0.995286  0.995286  6.238514
# 5      C7    1.0  0.657703  1.004670  1.163907  1.129861  1.129861  1.721924
# 6     C10    1.0  0.904694  0.721865  1.164370  1.204808  1.204808  2.731507
# 7     C11    1.0  0.865052  0.764883  0.962870  1.133247  1.133247  1.521255
# 8     C12    1.0  0.767070  0.703316  1.115127  1.628207  1.628207  2.420209
# 9      V1    1.0  1.405977  0.928877  0.987590  1.664402  1.664402  1.816920
# 10     V2    1.0  1.012444  0.881689  0.495635  1.067346  1.067346  1.072986
# 11     V3    1.0  1.308874  1.244828  0.578726  1.400165  1.400165  1.415863
# 12     V4    1.0  0.673629  0.717456  0.830478  0.886572  0.886572  1.938363
# 13     V5    1.0  0.728106  0.858893  0.725889  0.715402  0.715402  1.729459
# 14     V7    1.0  1.250577  0.850651  0.546575  1.541479  1.541479  0.861474
# 15     V8    1.0  0.777208  0.996183  1.225756  0.714914  0.714914  1.974718
# 16    V10    1.0  1.040522  1.125291  1.620258  1.116828  1.116828  3.013179
# 17    V12    1.0  0.690611  1.016503  0.740259  0.710119  0.710119  2.023988
#
#       OPALIN      FGF1
# 0   0.760802  0.540036
# 1   0.734416  0.731451
# 2   1.220706  0.726181
# 3   1.287364  1.332657
# 4   1.117382  2.706675
# 5   1.168546  1.119835
# 6   1.399859  0.925767
# 7   0.987008  0.855132
# 8   0.825741  0.991889
# 9   0.947143  1.065645
# 10  0.769386  1.004058
# 11  0.712303  1.254486
# 12  1.156550  0.865195
# 13  0.942064  0.890381
# 14  0.650435  0.961152
# 15  1.641415  1.103564
# 16  1.586906  1.669126
# 17  0.994868  1.224887

# %%
calibrator_df

# %%
plt.scatter(calibrator_df['GAPDH'], Y)  # Scatter plot

# Add labels and a title
plt.xlabel('Ct')
plt.ylabel('log(%)')
plt.title('GAPDH log(%) vs. GAPDH Ct')

# Show the plot
plt.show()

# %%
plt.scatter(calibrator_df['IGF2'], Y)  # Scatter plot

# Add labels and a title
plt.xlabel('Ct')
plt.ylabel('log(%)')
plt.title('IGF2 log(%) vs. IGF2 Ct')

# Show the plot
plt.show()

# %%
# Create a LinearRegression model
model = LinearRegression()

# Fit the model to the data
model.fit(GAPDH_LMX, GAPDH_LMY)

# Get the coefficients and intercept
coefficients = model.coef_
intercept = model.intercept_

# Make predictions
predictions = model.predict(GAPDH_LMX)

# Calculate R-squared
r_squared = model.score(GAPDH_LMX, GAPDH_LMY)

# Calculate Slope
slope = model.coef_[0]

print("R-squared:", r_squared)
print(f"Slope: {slope}")
print("Intercept:", intercept)
print("Coefficients:", coefficients)
